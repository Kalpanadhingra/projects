# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/cystanford/Titanic_Data/master/test.csv")
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# NaN is not a number or missing data
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df[["Name","Sex","Age","Ticket","Fare"]]
# Out:
#                                              Name     Sex   Age  \
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5
# 416                           Ware, Mr. Frederick    male   NaN
# 417                      Peter, Master. Michael J    male   NaN
#
#                  Ticket      Fare
# 0                330911    7.8292
# 1                363272    7.0000
# 2                240276    9.6875
# 3                315154    8.6625
# ...

# %%
df.dtypes=='object'
# Out:
# PassengerId    False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes=='float64'
# Out:
# PassengerId    False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes=='int64'
# Out:
# PassengerId     True
# Pclass          True
# Name           False
# Sex            False
# Age            False
# SibSp           True
# Parch           True
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[df.dtypes[df.dtypes=='object'].index]
# Out:
#                                              Name     Sex              Ticket  \
# 0                                Kelly, Mr. James    male              330911
# 1                Wilkes, Mrs. James (Ellen Needs)  female              363272
# 2                       Myles, Mr. Thomas Francis    male              240276
# 3                                Wirz, Mr. Albert    male              315154
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female             3101298
# ..                                            ...     ...                 ...
# 413                            Spector, Mr. Woolf    male           A.5. 3236
# 414                  Oliva y Ocana, Dona. Fermina  female            PC 17758
# 415                  Saether, Mr. Simon Sivertsen    male  SOTON/O.Q. 3101262
# 416                           Ware, Mr. Frederick    male              359309
# 417                      Peter, Master. Michael J    male                2668
#
#     Cabin Embarked
# ...

# %%
df[df.dtypes[df.dtypes=='float'].index]
# Out:
#       Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 413   NaN    8.0500
# 414  39.0  108.9000
# 415  38.5    7.2500
# 416   NaN    8.0500
# 417   NaN   22.3583
#
# [418 rows x 2 columns]

# %%
df.head(15)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Pclass                                             Name  \
# 408         1300       3                  Riordan, Miss. Johanna Hannah""
# 409         1301       3                        Peacock, Miss. Treasteall
# 410         1302       3                           Naughton, Miss. Hannah
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 413         1305       3                               Spector, Mr. Woolf
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
# 416         1308       3                              Ware, Mr. Frederick
# 417         1309       3                         Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 408  female   NaN      0      0              334915    7.7208   NaN        Q
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Ticket']]
# Out:
#                  Ticket
# 0                330911
# 1                363272
# 2                240276
# 3                315154
# 4               3101298
# ..                  ...
# 413           A.5. 3236
# 414            PC 17758
# 415  SOTON/O.Q. 3101262
# 416              359309
# 417                2668
#
# [418 rows x 1 columns]

# %%
df[['Ticket','Age']][4:16]
# Out:
#            Ticket   Age
# 4         3101298  22.0
# 5            7538  14.0
# 6          330972  30.0
# 7          248738  26.0
# 8            2657  18.0
# 9       A/4 48871  21.0
# 10         349220   NaN
# 11            694  46.0
# 12          21228  23.0
# 13          24065  63.0
# 14    W.E.P. 5734  47.0
# 15  SC/PARIS 2167  24.0

# %%
df[['Ticket','Age']][2:21:2]
# Out:
#               Ticket   Age
# 2             240276  62.0
# 4            3101298  22.0
# 6             330972  30.0
# 8               2657  18.0
# 10            349220   NaN
# 12             21228  23.0
# 14       W.E.P. 5734  47.0
# 16            233734  35.0
# 18  STON/O2. 3101270  27.0
# 20          PC 17603  55.0

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df['new_col'] =2

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df.insert(loc=3, column='food', value='yes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5808\397786920.py in ?()
# ----> 1 df.insert(loc=3, column='food', value='yes')
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    4768                 "'self.flags.allows_duplicate_labels' is False."
#    4769             )
#    4770         if not allow_duplicates and column in self.columns:
#    4771             # Should this be a different kind of error??
# -> 4772             raise ValueError(f"cannot insert {column}, already exists")
#    4773         if not isinstance(loc, int):
#    4774             raise TypeError("loc must be int")
#    4775
#
# ValueError: cannot insert food, already exists

# %%
df
# Out:
#      PassengerId  Pclass                                          Name food  \
# 0            892       3                              Kelly, Mr. James  yes
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)  yes
# 2            894       2                     Myles, Mr. Thomas Francis  yes
# 3            895       3                              Wirz, Mr. Albert  yes
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  yes
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf  yes
# 414         1306       1                  Oliva y Ocana, Dona. Fermina  yes
# 415         1307       3                  Saether, Mr. Simon Sivertsen  yes
# 416         1308       3                           Ware, Mr. Frederick  yes
# 417         1309       3                      Peter, Master. Michael J  yes
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
a= df['Name'][0:10]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a
# Out:
# 0                                Kelly, Mr. James
# 1                Wilkes, Mrs. James (Ellen Needs)
# 2                       Myles, Mr. Thomas Francis
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5                      Svensson, Mr. Johan Cervin
# 6                            Connolly, Miss. Kate
# 7                    Caldwell, Mr. Albert Francis
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9                         Davies, Mr. John Samuel
# Name: Name, dtype: object

# %%
l=['a0','a1','a2','a3','a4','a5','a6','a7','a8','a9']

# %%
pd.Series(a,index=l)
# Out:
# a0    NaN
# a1    NaN
# a2    NaN
# a3    NaN
# a4    NaN
# a5    NaN
# a6    NaN
# a7    NaN
# a8    NaN
# a9    NaN
# Name: Name, dtype: object

# %%
pd.Series(list(a),index=l)
# Out:
# a0                                Kelly, Mr. James
# a1                Wilkes, Mrs. James (Ellen Needs)
# a2                       Myles, Mr. Thomas Francis
# a3                                Wirz, Mr. Albert
# a4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# a5                      Svensson, Mr. Johan Cervin
# a6                            Connolly, Miss. Kate
# a7                    Caldwell, Mr. Albert Francis
# a8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# a9                         Davies, Mr. John Samuel
# dtype: object

# %%
m1=pd.Series([100,200,300,400,500], index=[1,2,3,4,5])

# %%
m1
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2= pd.Series([600,700,800,900,1000],index=[1,2,3,4,5])

# %%
m2
# Out:
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3=pd.concat([m1,m2])

# %%
m3
# Out:
# 1     100
# 2     200
# 3     300
# 4     400
# 5     500
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3[1]
# Out:
# 1    100
# 1    600
# dtype: int64

# %%
m1*m2
# Out:
# 1     60000
# 2    140000
# 3    240000
# 4    360000
# 5    500000
# dtype: int64

# %%
m1+m2
# Out:
# 1     700
# 2     900
# 3    1100
# 4    1300
# 5    1500
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name food  \
# 0          892       3                              Kelly, Mr. James  yes
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  yes
# 2          894       2                     Myles, Mr. Thomas Francis  yes
# 3          895       3                              Wirz, Mr. Albert  yes
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  yes
#
#       Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked  new_col  \
# 0    male  34.5      0      0   330911   7.8292   NaN        Q        2
# 1  female  47.0      1      0   363272   7.0000   NaN        S        2
# 2    male  62.0      0      0   240276   9.6875   NaN        Q        2
# 3    male  27.0      0      0   315154   8.6625   NaN        S        2
# 4  female  22.0      1      1  3101298  12.2875   NaN        S        2
#
#    new_row
# 0       -1
# 1       -1
# 2       -1
# 3       -1
# 4       -1

# %% [markdown]
# ### to delete a column

# %%
df.drop('new_row',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 df.drop('new_row',axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df.drop('new_col',axis=1,inplace=True)

# %%
df.drop('new_row',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name food  \
# 0            892       3                              Kelly, Mr. James  yes
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)  yes
# 2            894       2                     Myles, Mr. Thomas Francis  yes
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  yes
# 5            897       3                    Svensson, Mr. Johan Cervin  yes
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf  yes
# 414         1306       1                  Oliva y Ocana, Dona. Fermina  yes
# 415         1307       3                  Saether, Mr. Simon Sivertsen  yes
# 416         1308       3                           Ware, Mr. Frederick  yes
# 417         1309       3                      Peter, Master. Michael J  yes
#
# ...

# %% [markdown]
# ### to delete a particular row
#
# 3rd row is already deleted by me but not in thiscode

# %%
df.drop(2)
# Out:
#      PassengerId  Pclass                                          Name food  \
# 0            892       3                              Kelly, Mr. James  yes
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)  yes
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  yes
# 5            897       3                    Svensson, Mr. Johan Cervin  yes
# 6            898       3                          Connolly, Miss. Kate  yes
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf  yes
# 414         1306       1                  Oliva y Ocana, Dona. Fermina  yes
# 415         1307       3                  Saether, Mr. Simon Sivertsen  yes
# 416         1308       3                           Ware, Mr. Frederick  yes
# 417         1309       3                      Peter, Master. Michael J  yes
#
# ...

# %%
df
# Out:
#      PassengerId  Pclass                                          Name food  \
# 0            892       3                              Kelly, Mr. James  yes
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)  yes
# 2            894       2                     Myles, Mr. Thomas Francis  yes
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  yes
# 5            897       3                    Svensson, Mr. Johan Cervin  yes
# ..           ...     ...                                           ...  ...
# 413         1305       3                            Spector, Mr. Woolf  yes
# 414         1306       1                  Oliva y Ocana, Dona. Fermina  yes
# 415         1307       3                  Saether, Mr. Simon Sivertsen  yes
# 416         1308       3                           Ware, Mr. Frederick  yes
# 417         1309       3                      Peter, Master. Michael J  yes
#
# ...

# %%
df.drop(2,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name food  \
# 0          892       3                              Kelly, Mr. James  yes
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  yes
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  yes
# 5          897       3                    Svensson, Mr. Johan Cervin  yes
# 6          898       3                          Connolly, Miss. Kate  yes
#
#       Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0    male  34.5      0      0   330911   7.8292   NaN        Q
# 1  female  47.0      1      0   363272   7.0000   NaN        S
# 4  female  22.0      1      1  3101298  12.2875   NaN        S
# 5    male  14.0      0      0     7538   9.2250   NaN        S
# 6  female  30.0      0      0   330972   7.6292   NaN        Q

# %% [markdown]
# ### to convert  a particular column as index

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                               PassengerId  Pclass food  \
# Name
# Kelly, Mr. James                                      892       3  yes
# Wilkes, Mrs. James (Ellen Needs)                      893       3  yes
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  yes
# Svensson, Mr. Johan Cervin                            897       3  yes
# Connolly, Miss. Kate                                  898       3  yes
# ...                                                   ...     ...  ...
# Spector, Mr. Woolf                                   1305       3  yes
# Oliva y Ocana, Dona. Fermina                         1306       1  yes
# Saether, Mr. Simon Sivertsen                         1307       3  yes
# Ware, Mr. Frederick                                  1308       3  yes
# Peter, Master. Michael J                             1309       3  yes
#
#                                                  Sex   Age  SibSp  Parch  \
# Name
# ...

# %%
# Out:
#                                               PassengerId  Pclass food  \
# Name
# Kelly, Mr. James                                      892       3  yes
# Wilkes, Mrs. James (Ellen Needs)                      893       3  yes
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  yes
# Svensson, Mr. Johan Cervin                            897       3  yes
# Connolly, Miss. Kate                                  898       3  yes
# ...                                                   ...     ...  ...
# Spector, Mr. Woolf                                   1305       3  yes
# Oliva y Ocana, Dona. Fermina                         1306       1  yes
# Saether, Mr. Simon Sivertsen                         1307       3  yes
# Ware, Mr. Frederick                                  1308       3  yes
# Peter, Master. Michael J                             1309       3  yes
#
#                                                  Sex   Age  SibSp  Parch  \
# Name
# ...

# %%
df.reset_index()
# Out:
#                                              Name  PassengerId  Pclass food  \
# 0                                Kelly, Mr. James          892       3  yes
# 1                Wilkes, Mrs. James (Ellen Needs)          893       3  yes
# 2    Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  yes
# 3                      Svensson, Mr. Johan Cervin          897       3  yes
# 4                            Connolly, Miss. Kate          898       3  yes
# ..                                            ...          ...     ...  ...
# 411                            Spector, Mr. Woolf         1305       3  yes
# 412                  Oliva y Ocana, Dona. Fermina         1306       1  yes
# 413                  Saether, Mr. Simon Sivertsen         1307       3  yes
# 414                           Ware, Mr. Frederick         1308       3  yes
# 415                      Peter, Master. Michael J         1309       3  yes
#
# ...

# %%
df
# Out:
#                                               PassengerId  Pclass food  \
# Name
# Kelly, Mr. James                                      892       3  yes
# Wilkes, Mrs. James (Ellen Needs)                      893       3  yes
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  yes
# Svensson, Mr. Johan Cervin                            897       3  yes
# Connolly, Miss. Kate                                  898       3  yes
# ...                                                   ...     ...  ...
# Spector, Mr. Woolf                                   1305       3  yes
# Oliva y Ocana, Dona. Fermina                         1306       1  yes
# Saether, Mr. Simon Sivertsen                         1307       3  yes
# Ware, Mr. Frederick                                  1308       3  yes
# Peter, Master. Michael J                             1309       3  yes
#
#                                                  Sex   Age  SibSp  Parch  \
# Name
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                              Name  PassengerId  Pclass food  \
# 0                                Kelly, Mr. James          892       3  yes
# 1                Wilkes, Mrs. James (Ellen Needs)          893       3  yes
# 2    Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  yes
# 3                      Svensson, Mr. Johan Cervin          897       3  yes
# 4                            Connolly, Miss. Kate          898       3  yes
# ..                                            ...          ...     ...  ...
# 411                            Spector, Mr. Woolf         1305       3  yes
# 412                  Oliva y Ocana, Dona. Fermina         1306       1  yes
# 413                  Saether, Mr. Simon Sivertsen         1307       3  yes
# 414                           Ware, Mr. Frederick         1308       3  yes
# 415                      Peter, Master. Michael J         1309       3  yes
#
# ...

# %% [markdown]
# # making a dataframe from using dictionary

# %%
d={"Name":['kalpana','deepanshu','swati','aditya','bhumi'],
  "Age":[19,19,18,15,1],
  "class":['grad.','grad.','grad','10th','prenursery']}
print(d)
# Out:
# {'Name': ['kalpana', 'deepanshu', 'swati', 'aditya', 'bhumi'], 'Age': [19, 19, 18, 15, 1], 'class': ['grad.', 'grad.', 'grad', '10th', 'prenursery']}

# %%
pd.DataFrame(d)
# Out:
#         Name  Age       class
# 0    kalpana   19       grad.
# 1  deepanshu   19       grad.
# 2      swati   18        grad
# 3     aditya   15        10th
# 4      bhumi    1  prenursery

# %%
df1=pd.read_csv("https://raw.githubusercontent.com/robmjk/PYTHON_data_processing_and_visualization/main/Taxon-Jan2018.csv")

# %%
df1
# Out:
#            Reptile - Snake - Terrestrial   28  5.65%
# 0          Avian - Domestic/Feral/Exotic   26  5.24%
# 1                   Marsupial - Macropod   17  3.43%
# 2                       Reptile - Lizard   32  6.45%
# 3                Avian - Seabird/Pelican   48  9.68%
# 4                        Reptile - Feral    3   0.6%
# 5               Amphibian - Feral/Exotic    2   0.4%
# 6                      Avian - Waterbird   28  5.65%
# 7                          Avian - Other  188  37.9%
# 8                         Avian - Raptor   19  3.83%
# 9             Eutherian - Bat - Microbat   24  4.84%
# 10          Eutherian - Bat - Flying Fox    6  1.21%
# 11           Eutherian - Domestic/ Feral   10  2.02%
# 12             Reptile - Turtle - Marine    6  1.21%
# 13             Eutherian - Marine mammal   10  2.02%
# 14         Reptile - Turtle - Freshwater   15  3.02%
# 15               Amphibian - Native Frog   15  3.02%
# 16                  Marsupial - Dasyurid    8  1.61%
# ...

# %%
df1.dropna()    # to delete Nan values in rows
# Out:
#            Reptile - Snake - Terrestrial   28  5.65%
# 0          Avian - Domestic/Feral/Exotic   26  5.24%
# 1                   Marsupial - Macropod   17  3.43%
# 2                       Reptile - Lizard   32  6.45%
# 3                Avian - Seabird/Pelican   48  9.68%
# 4                        Reptile - Feral    3   0.6%
# 5               Amphibian - Feral/Exotic    2   0.4%
# 6                      Avian - Waterbird   28  5.65%
# 7                          Avian - Other  188  37.9%
# 8                         Avian - Raptor   19  3.83%
# 9             Eutherian - Bat - Microbat   24  4.84%
# 10          Eutherian - Bat - Flying Fox    6  1.21%
# 11           Eutherian - Domestic/ Feral   10  2.02%
# 12             Reptile - Turtle - Marine    6  1.21%
# 13             Eutherian - Marine mammal   10  2.02%
# 14         Reptile - Turtle - Freshwater   15  3.02%
# 15               Amphibian - Native Frog   15  3.02%
# 16                  Marsupial - Dasyurid    8  1.61%
# ...

# %%
df
# Out:
#                                              Name  PassengerId  Pclass food  \
# 0                                Kelly, Mr. James          892       3  yes
# 1                Wilkes, Mrs. James (Ellen Needs)          893       3  yes
# 2    Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  yes
# 3                      Svensson, Mr. Johan Cervin          897       3  yes
# 4                            Connolly, Miss. Kate          898       3  yes
# ..                                            ...          ...     ...  ...
# 411                            Spector, Mr. Woolf         1305       3  yes
# 412                  Oliva y Ocana, Dona. Fermina         1306       1  yes
# 413                  Saether, Mr. Simon Sivertsen         1307       3  yes
# 414                           Ware, Mr. Frederick         1308       3  yes
# 415                      Peter, Master. Michael J         1309       3  yes
#
# ...

# %%
df.dropna()
# Out:
#                                                   Name  PassengerId  Pclass  \
# 10       Snyder, Mrs. John Pillsbury (Nelle Stevenson)          904       1
# 12   Chaffee, Mrs. Herbert Fuller (Carrie Constance...          906       1
# 22     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)          916       1
# 24                        Ostby, Miss. Helene Ragnhild          918       1
# 26                             Brady, Mr. John Bertram          920       1
# ..                                                 ...          ...     ...
# 402                       Frauenthal, Mr. Isaac Gerald         1296       1
# 403       Nourney, Mr. Alfred (Baron von Drachstedt")"         1297       2
# 405                         Widener, Mr. George Dunton         1299       1
# 409    Minahan, Mrs. William Edward (Lillian E Thorpe)         1303       1
# 412                       Oliva y Ocana, Dona. Fermina         1306       1
#
# ...

# %%
df    # not permanent delete
# Out:
#                                              Name  PassengerId  Pclass food  \
# 0                                Kelly, Mr. James          892       3  yes
# 1                Wilkes, Mrs. James (Ellen Needs)          893       3  yes
# 2    Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896       3  yes
# 3                      Svensson, Mr. Johan Cervin          897       3  yes
# 4                            Connolly, Miss. Kate          898       3  yes
# ..                                            ...          ...     ...  ...
# 411                            Spector, Mr. Woolf         1305       3  yes
# 412                  Oliva y Ocana, Dona. Fermina         1306       1  yes
# 413                  Saether, Mr. Simon Sivertsen         1307       3  yes
# 414                           Ware, Mr. Frederick         1308       3  yes
# 415                      Peter, Master. Michael J         1309       3  yes
#
# ...

# %%
df.dropna(inplace=True)

# %%
df    # deleted permanently
# Out:
#                                                   Name  PassengerId  Pclass  \
# 10       Snyder, Mrs. John Pillsbury (Nelle Stevenson)          904       1
# 12   Chaffee, Mrs. Herbert Fuller (Carrie Constance...          906       1
# 22     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)          916       1
# 24                        Ostby, Miss. Helene Ragnhild          918       1
# 26                             Brady, Mr. John Bertram          920       1
# ..                                                 ...          ...     ...
# 402                       Frauenthal, Mr. Isaac Gerald         1296       1
# 403       Nourney, Mr. Alfred (Baron von Drachstedt")"         1297       2
# 405                         Widener, Mr. George Dunton         1299       1
# 409    Minahan, Mrs. William Edward (Lillian E Thorpe)         1303       1
# 412                       Oliva y Ocana, Dona. Fermina         1306       1
#
# ...

# %%
#to delete columns also

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/cystanford/Titanic_Data/master/test.csv")

# %%
df2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df2.dropna(axis=1)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex  SibSp  Parch              Ticket Embarked
# 0      male      0      0              330911        Q
# ...

# %%
## we want to replace NaN by our own word like , we want to display kalpana instead of NaN

# %%
df3=pd.read_csv("https://raw.githubusercontent.com/cystanford/Titanic_Data/master/test.csv")

# %%
df3
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df3.fillna("kalpana",inplace=True)

# %%
df3
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex      Age  SibSp  Parch              Ticket     Fare    Cabin  \
# ...
